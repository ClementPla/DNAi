# %%
# %load_ext autoreload
# %autoreload 2


import pandas as pd
from bokeh.io import  output_notebook, show, export_png
import numpy as np
from bokeh.plotting import figure

from bokeh.models import CategoricalColorMapper, Legend
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_pickle("properties_with_IA.pkl")

df = df[np.isin(df.fiber_type, ["double", "multiple"])]


# Counts the number of occurences of each annotators
results = dict()
for annotator in df['annotator'].unique():
    df_annotator = df.loc[df['annotator'] == annotator]
    value_count = df_annotator['common'].value_counts()
    results[annotator] = (list(value_count.sort_index()), len(df_annotator))

output_notebook()


if len(df['annotator'].unique()) == 5:
    colors = ["#d20f39"]
else:
    colors = []
colors += ["#e78284", "#f5a97f", "#eed49f", "#a6d189"]


annotators = list(results.keys())
values = [results[annotator][0] for annotator in annotators]
data =  {f'Found by {i+1}': [int(v[i]) for v in values] for i in range(len(values[0]))}
y = list(data.keys())
data['annotators'] = annotators

p = figure(title="Counts of common fibers by annotator", x_range=annotators,
           height=400, tooltips="$name @annotators: @$name", toolbar_location=None,)
p.add_layout(Legend(), 'right')
p.vbar_stack(y, x='annotators', width=0.9, source=data, color=colors, legend_label=y,)
for i, a in enumerate(annotators):
    total = 0
    for v in values[i]:
        p.text(x=[a], y=v + total - 5, text=[str(v)], text_color="#24273a", 
               text_align="center", text_baseline="middle", angle=0)
        total += v
  
p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ebc12430-f2f0-424d-bdc6-f78a9206e636">Loading BokehJS ...</span>
#     </div>
#   <div id="e776e06e-21b1-4941-b7d5-b145d67658bd" data-root-id="p4043" style="display: contents;"></div>

# %%
df
# Out:
#             annotator        image_type  red  green     ratio fiber_type  \
# 0                   S  siMMS22L_+dox-01   86    129  0.666667     double
# 1                   S  siMMS22L_+dox-01  226    211  1.071090   multiple
# 2                   S  siMMS22L_+dox-01  110    125  0.880000     double
# 3                   S  siMMS22L_+dox-01   21     38  0.552632     double
# 5                   S  siMMS22L_+dox-01   28     91  0.307692     double
# ..                ...               ...  ...    ...       ...        ...
# 642  SegFormer MiT-B4     59_siBRCA2-02   11     18  0.611111     double
# 643  SegFormer MiT-B4     59_siBRCA2-02   22     13  1.692308     double
# 644  SegFormer MiT-B4     59_siBRCA2-02   40     55  0.727273     double
# 645  SegFormer MiT-B4     59_siBRCA2-02    9     27  0.333333     double
# 646  SegFormer MiT-B4     59_siBRCA2-02   31     40  0.775000     double
#
#          S      H      Y      C  SegFormer MiT-B4  common
# 0     True   True  False  False             False       2
# 1     True  False  False  False             False       1
# 2     True   True   True   True              True       5
# 3     True  False   True   True              True       4
# 5     True   True   True   True              True       5
# ..     ...    ...    ...    ...               ...     ...
# 642  False  False  False  False              True       1
# 643   True  False   True   True              True       4
# 644  False  False  False  False              True       1
# 645  False  False  False  False              True       1
# 646  False  False  False  False              True       1
#
# [593 rows x 12 columns]
